# %%
# !pip install wfdb
# !pip install neurokit2
# Out:
# Requirement already satisfied: wfdb in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.12.13)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2025.5.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.7.2)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.26.4)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.2.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.32.4)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.15.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.20.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2025.6.15)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.26.4->wfdb) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.26.4->wfdb) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.26.4->wfdb) (2024.2.0)
# Requirement already satisfied: neurokit2 in /usr/local/lib/python3.11/dist-packages (0.2.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from neurokit2) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from neurokit2) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.2.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (3.7.2)
# Requirement already satisfied: PyWavelets>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (2.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->neurokit2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->neurokit2) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (2025.6.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->neurokit2) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->neurokit2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->neurokit2) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->neurokit2) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->neurokit2) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->neurokit2) (2024.2.0)

# %%
# apnea_single_split_eval.py
# High-Accuracy Apnea Detection (CNN + BiLSTM + Transformer)
# Single train/test split + detailed metrics
# Modified: Midpoint+1 Rule for apnea labeling + automatic balancing + removed ROC

import os, wfdb, numpy as np
from scipy.signal import butter, filtfilt, find_peaks
from scipy.interpolate import interp1d
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, f1_score, cohen_kappa_score, classification_report,
    confusion_matrix, precision_recall_fscore_support
)
from torch.utils.data import Dataset, DataLoader
import torch, torch.nn as nn, torch.nn.functional as F
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import seaborn as sns

# ---------------------------
# Config
# ---------------------------
DATASET_PATH = "/kaggle/input/adult-sleep-apnea/apnea-ecg-database-1.0.0/apnea-ecg-database-1.0.0"
ORIG_FS = 100
WIN_MIN = 9  # you can change to 5 if needed
STRIDE_MIN = 1
WIN_SIZE = ORIG_FS * 60 * WIN_MIN
STEP = ORIG_FS * 60 * STRIDE_MIN
SEQ_LEN = 300
BATCH_SIZE = 32
EPOCHS = 25
LR = 1e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42
TEST_SIZE = 0.2  # 80/20 split

torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# ---------------------------
# Preprocessing
# ---------------------------
def bandpass(sig, fs=ORIG_FS, low=3.0, high=45.0, order=4):
    nyq = 0.5*fs
    b, a = butter(order, [low/nyq, high/nyq], btype="band")
    return filtfilt(b, a, sig)

def detect_rpeaks(sig, fs=ORIG_FS):
    sig = sig - np.median(sig)
    th = np.median(np.abs(sig)) + 0.5*np.std(sig)
    min_dist = int(0.35*fs)
    peaks, _ = find_peaks(np.abs(sig), height=th, distance=min_dist)
    return peaks

def build_rri_ra(segment, fs=ORIG_FS):
    peaks = detect_rpeaks(segment, fs)
    if len(peaks) < 2:
        return None
    rri = np.diff(peaks) * 1000 / fs
    ra = segment[peaks[:-1]]
    return rri.astype(np.float32), ra.astype(np.float32)

def resample_seq(seq, target_len=SEQ_LEN):
    if len(seq) < 2:
        return np.zeros(target_len, dtype=np.float32)
    x_old = np.linspace(0, 1, len(seq))
    x_new = np.linspace(0, 1, target_len)
    f = interp1d(x_old, seq, kind="linear", fill_value="extrapolate")
    return f(x_new).astype(np.float32)

def augment_signal(sig):
    if random.random() < 0.5:
        sig = sig + 0.01*np.random.randn(len(sig))
    if random.random() < 0.5:
        sig = sig * (0.9 + 0.2*np.random.rand())
    if random.random() < 0.3:
        shift = int(0.05*len(sig))
        sig = np.roll(sig, shift)
    return sig

# ---------------------------
# Index Builder with Midpoint+1 Rule and printing
# ---------------------------
def build_index(records, win_min=WIN_MIN, print_windows=False):
    idx = []
    for rec in records:
        try:
            ann = wfdb.rdann(os.path.join(DATASET_PATH, rec), "apn")
            labels = ann.symbol
            total_len = wfdb.rdrecord(os.path.join(DATASET_PATH, rec)).p_signal.shape[0]
        except Exception:
            continue

        starts = range(0, total_len - WIN_SIZE + 1, STEP)
        for s in starts:
            start_min = s // (ORIG_FS * 60)
            end_min = start_min + win_min
            window_labels = labels[start_min:end_min]

            if len(window_labels) < win_min:
                continue

            mid_idx = win_min // 2
            mid_label = window_labels[mid_idx]
            lab = 1 if mid_label == "A" else 0
            idx.append((rec, s, lab))

            if print_windows:
                print(f"Record {rec} - Window minutes {start_min}-{end_min-1}")
                print(f"  Midpoint minute: {start_min + mid_idx} -> mid_label: {mid_label}")
                print(f"  Assigned label: {lab}")
                print("-"*50)
    return idx

# ---------------------------
# Dataset class
# ---------------------------
class ApneaDataset(Dataset):
    def __init__(self, index, seq_len=SEQ_LEN, augment=False):
        self.seq_len = seq_len
        self.augment = augment
        random.shuffle(index)
        self.index = index

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        rec, s, label = self.index[idx]
        rec_path = os.path.join(DATASET_PATH, rec)
        sig = wfdb.rdrecord(rec_path).p_signal[:, 0].astype(np.float32)

        window = sig[s:s + WIN_SIZE]
        if self.augment:
            window = augment_signal(window)

        window = bandpass(window)
        result = build_rri_ra(window)

        if result is None:
            feat_seq = np.zeros((self.seq_len, 2), dtype=np.float32)
        else:
            rri, ra = result
            rri = (rri - np.mean(rri)) / (np.std(rri) + 1e-6)
            ra = (ra - np.mean(ra)) / (np.std(ra) + 1e-6)
            feat_seq = np.stack(
                [resample_seq(rri, self.seq_len),
                 resample_seq(ra, self.seq_len)],
                axis=1
            )

        return torch.from_numpy(feat_seq), torch.tensor(label, dtype=torch.long)

# ---------------------------
# Model definitions
# ---------------------------
class BranchCNNLSTM(nn.Module):
    def __init__(self, in_ch=2, conv_ch=64, hidden=128):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(in_ch, conv_ch, 7, padding=3), nn.ReLU(), nn.BatchNorm1d(conv_ch),
            nn.Conv1d(conv_ch, conv_ch, 5, padding=2), nn.ReLU(), nn.BatchNorm1d(conv_ch),
            nn.Conv1d(conv_ch, conv_ch, 3, padding=1), nn.ReLU(), nn.BatchNorm1d(conv_ch),
        )
        self.pool = nn.AdaptiveAvgPool1d(100)
        self.lstm = nn.LSTM(conv_ch, hidden, batch_first=True, bidirectional=True)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.conv(x)
        x = self.pool(x)
        x = x.permute(0, 2, 1)
        _, (h, _) = self.lstm(x)
        return torch.cat([h[-2], h[-1]], dim=1)

class ApneaNet(nn.Module):
    def __init__(self, hidden=128, proj_dim=256):
        super().__init__()
        self.branch = BranchCNNLSTM(2, 64, hidden)
        self.proj = nn.Linear(hidden*2, proj_dim)
        encoder = nn.TransformerEncoderLayer(
            d_model=proj_dim, nhead=8, dim_feedforward=512, dropout=0.3, batch_first=True
        )
        self.trans = nn.TransformerEncoder(encoder, num_layers=3)
        self.fc = nn.Sequential(
            nn.Linear(proj_dim, 128), nn.ReLU(), nn.Dropout(0.5),
            nn.Linear(128, 2)
        )

    def forward(self, x):
        bfeat = self.branch(x)
        tokens = self.proj(bfeat).unsqueeze(1)
        out = self.trans(tokens).mean(dim=1)
        return self.fc(out)

# ---------------------------
# Training and evaluation
# ---------------------------
def train_one_epoch(model, loader, opt, crit):
    model.train()
    total_loss = 0.0
    pbar = tqdm(loader, desc="Training")
    for X, y in pbar:
        X, y = X.to(DEVICE), y.to(DEVICE)
        opt.zero_grad()
        out = model(X)
        loss = crit(out, y)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 5.0)
        opt.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader):
    model.eval()
    preds, gts, probs = [], [], []
    with torch.no_grad():
        for X, y in loader:
            X = X.to(DEVICE)
            out = model(X)
            p = F.softmax(out, dim=1).cpu().numpy()
            pred = out.argmax(1).cpu().tolist()
            preds += pred
            gts += y.tolist()
            probs += p.tolist()
    return np.array(gts), np.array(preds), np.array(probs)

def plot_confusion(cm, fold_label=""):
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=["Non-Apnea","Apnea"], yticklabels=["Non-Apnea","Apnea"])
    plt.title(f"Confusion Matrix {fold_label}")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

# ---------------------------
# Main
# ---------------------------
if __name__ == "__main__":
    records = [f"a{str(i).zfill(2)}" for i in range(1, 21)]

    # Build index and print sliding window labels
    index = build_index(records, win_min=WIN_MIN, print_windows=True)
    if len(index) == 0:
        raise RuntimeError("No index entries found.")

    # Count labels
    labels = np.array([x[2] for x in index])
    apnea_count = np.sum(labels == 1)
    non_apnea_count = np.sum(labels == 0)
    print(f"\nBefore balancing -> Apnea: {apnea_count}, Non-Apnea: {non_apnea_count}")

    # Separate by class
    pos_list = [x for x in index if x[2] == 1]
    neg_list = [x for x in index if x[2] == 0]

    # Determine target based on smaller class
    target = min(apnea_count, non_apnea_count)
    print(f"Target samples per class (balanced): {target}")

    def get_fixed_samples(lst, target, rng_seed=SEED):
        random.seed(rng_seed)
        if len(lst) >= target:
            return random.sample(lst, target)
        else:
            extra = random.choices(lst, k=(target - len(lst)))
            return lst + extra

    pos_samples = get_fixed_samples(pos_list, target)
    neg_samples = get_fixed_samples(neg_list, target)

    balanced_index = pos_samples + neg_samples
    random.shuffle(balanced_index)

    labels_balanced = np.array([x[2] for x in balanced_index])
    print(f"After balancing -> Apnea: {np.sum(labels_balanced == 1)}, Non-Apnea: {np.sum(labels_balanced == 0)}")

    # Train/test split
    train_idx, test_idx = train_test_split(
        np.arange(len(balanced_index)), test_size=TEST_SIZE,
        stratify=labels_balanced, random_state=SEED
    )
    train_index = [balanced_index[i] for i in train_idx]
    test_index = [balanced_index[i] for i in test_idx]

    train_ds = ApneaDataset(train_index, augment=True)
    test_ds = ApneaDataset(test_index, augment=False)
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE)

    # Model, optimizer, criterion
    model = ApneaNet().to(DEVICE)
    opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=EPOCHS)
    crit = nn.CrossEntropyLoss()

    # Training
    for ep in range(EPOCHS):
        loss = train_one_epoch(model, train_loader, opt, crit)
        scheduler.step()
        print(f"Epoch {ep+1}/{EPOCHS} - Train Loss: {loss:.4f}")

    # Evaluation
    gts, preds, probs = evaluate(model, test_loader)

    acc = accuracy_score(gts, preds)
    f1 = f1_score(gts, preds, zero_division=0)
    kappa = cohen_kappa_score(gts, preds)
    print("\n=== Overall Metrics ===")
    print(f"Accuracy: {acc:.4f}")
    print(f"F1-score (binary): {f1:.4f}")
    print(f"Cohen's Kappa: {kappa:.4f}")

    print("\n=== Classification Report (per-class) ===")
    print(classification_report(gts, preds, target_names=["Non-Apnea","Apnea"], zero_division=0))

    cm = confusion_matrix(gts, preds)
    plot_confusion(cm)

    sens = []
    for i in range(cm.shape[0]):
        tp = cm[i, i]
        fn = cm[i, :].sum() - tp
        recall_i = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        sens.append(recall_i)
        print(f"Sensitivity (Recall) for class {i} ({'Non-Apnea' if i==0 else 'Apnea'}): {recall_i:.4f}")

    p_r_f_macro = precision_recall_fscore_support(gts, preds, average="macro", zero_division=0)
    p_r_f_micro = precision_recall_fscore_support(gts, preds, average="micro", zero_division=0)
    p_r_f_weighted = precision_recall_fscore_support(gts, preds, average="weighted", zero_division=0)
    print("\n=== Averages ===")
    print(f"Macro - Precision: {p_r_f_macro[0]:.4f}, Recall: {p_r_f_macro[1]:.4f}, F1: {p_r_f_macro[2]:.4f}")
    print(f"Micro - Precision: {p_r_f_micro[0]:.4f}, Recall: {p_r_f_micro[1]:.4f}, F1: {p_r_f_micro[2]:.4f}")
    print(f"Weighted - Precision: {p_r_f_weighted[0]:.4f}, Recall: {p_r_f_weighted[1]:.4f}, F1: {p_r_f_weighted[2]:.4f}")

    print("\nConfusion Matrix (raw counts):")
    print(cm)
# Out:
# Record a01 - Window minutes 0-8
#   Midpoint minute: 4 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 1-9
#   Midpoint minute: 5 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 2-10
#   Midpoint minute: 6 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 3-11
#   Midpoint minute: 7 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 4-12
#   Midpoint minute: 8 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 5-13
#   Midpoint minute: 9 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 6-14
#   Midpoint minute: 10 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 7-15
#   Midpoint minute: 11 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 8-16
#   Midpoint minute: 12 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 9-17
#   Midpoint minute: 13 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 10-18
#   Midpoint minute: 14 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 11-19
#   Midpoint minute: 15 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 12-20
#   Midpoint minute: 16 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 13-21
#   Midpoint minute: 17 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 14-22
#   Midpoint minute: 18 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 15-23
#   Midpoint minute: 19 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 16-24
#   Midpoint minute: 20 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 17-25
#   Midpoint minute: 21 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 18-26
#   Midpoint minute: 22 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 19-27
#   Midpoint minute: 23 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 20-28
#   Midpoint minute: 24 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 21-29
#   Midpoint minute: 25 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 22-30
#   Midpoint minute: 26 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 23-31
#   Midpoint minute: 27 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 24-32
#   Midpoint minute: 28 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 25-33
#   Midpoint minute: 29 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 26-34
#   Midpoint minute: 30 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 27-35
#   Midpoint minute: 31 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 28-36
#   Midpoint minute: 32 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 29-37
#   Midpoint minute: 33 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 30-38
#   Midpoint minute: 34 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 31-39
#   Midpoint minute: 35 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 32-40
#   Midpoint minute: 36 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 33-41
#   Midpoint minute: 37 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 34-42
#   Midpoint minute: 38 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 35-43
#   Midpoint minute: 39 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 36-44
#   Midpoint minute: 40 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 37-45
#   Midpoint minute: 41 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 38-46
#   Midpoint minute: 42 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 39-47
#   Midpoint minute: 43 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 40-48
#   Midpoint minute: 44 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 41-49
#   Midpoint minute: 45 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 42-50
#   Midpoint minute: 46 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 43-51
#   Midpoint minute: 47 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 44-52
#   Midpoint minute: 48 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 45-53
#   Midpoint minute: 49 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 46-54
#   Midpoint minute: 50 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 47-55
#   Midpoint minute: 51 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 48-56
#   Midpoint minute: 52 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 49-57
#   Midpoint minute: 53 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 50-58
#   Midpoint minute: 54 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 51-59
#   Midpoint minute: 55 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 52-60
#   Midpoint minute: 56 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 53-61
#   Midpoint minute: 57 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 54-62
#   Midpoint minute: 58 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 55-63
#   Midpoint minute: 59 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 56-64
#   Midpoint minute: 60 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 57-65
#   Midpoint minute: 61 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 58-66
#   Midpoint minute: 62 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 59-67
#   Midpoint minute: 63 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 60-68
#   Midpoint minute: 64 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 61-69
#   Midpoint minute: 65 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 62-70
#   Midpoint minute: 66 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 63-71
#   Midpoint minute: 67 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 64-72
#   Midpoint minute: 68 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 65-73
#   Midpoint minute: 69 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 66-74
#   Midpoint minute: 70 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 67-75
#   Midpoint minute: 71 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 68-76
#   Midpoint minute: 72 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 69-77
#   Midpoint minute: 73 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 70-78
#   Midpoint minute: 74 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 71-79
#   Midpoint minute: 75 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 72-80
#   Midpoint minute: 76 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 73-81
#   Midpoint minute: 77 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 74-82
#   Midpoint minute: 78 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 75-83
#   Midpoint minute: 79 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 76-84
#   Midpoint minute: 80 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 77-85
#   Midpoint minute: 81 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 78-86
#   Midpoint minute: 82 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 79-87
#   Midpoint minute: 83 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 80-88
#   Midpoint minute: 84 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 81-89
#   Midpoint minute: 85 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 82-90
#   Midpoint minute: 86 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 83-91
#   Midpoint minute: 87 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 84-92
#   Midpoint minute: 88 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 85-93
#   Midpoint minute: 89 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 86-94
#   Midpoint minute: 90 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 87-95
#   Midpoint minute: 91 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 88-96
#   Midpoint minute: 92 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 89-97
#   Midpoint minute: 93 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 90-98
#   Midpoint minute: 94 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 91-99
#   Midpoint minute: 95 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 92-100
#   Midpoint minute: 96 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 93-101
#   Midpoint minute: 97 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 94-102
#   Midpoint minute: 98 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 95-103
#   Midpoint minute: 99 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 96-104
#   Midpoint minute: 100 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 97-105
#   Midpoint minute: 101 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 98-106
#   Midpoint minute: 102 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 99-107
#   Midpoint minute: 103 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 100-108
#   Midpoint minute: 104 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 101-109
#   Midpoint minute: 105 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 102-110
#   Midpoint minute: 106 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 103-111
#   Midpoint minute: 107 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 104-112
#   Midpoint minute: 108 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 105-113
#   Midpoint minute: 109 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 106-114
#   Midpoint minute: 110 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 107-115
#   Midpoint minute: 111 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 108-116
#   Midpoint minute: 112 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 109-117
#   Midpoint minute: 113 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 110-118
#   Midpoint minute: 114 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 111-119
#   Midpoint minute: 115 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 112-120
#   Midpoint minute: 116 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 113-121
#   Midpoint minute: 117 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 114-122
#   Midpoint minute: 118 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 115-123
#   Midpoint minute: 119 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 116-124
#   Midpoint minute: 120 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 117-125
#   Midpoint minute: 121 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 118-126
#   Midpoint minute: 122 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 119-127
#   Midpoint minute: 123 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 120-128
#   Midpoint minute: 124 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 121-129
#   Midpoint minute: 125 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 122-130
#   Midpoint minute: 126 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 123-131
#   Midpoint minute: 127 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 124-132
#   Midpoint minute: 128 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 125-133
#   Midpoint minute: 129 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 126-134
#   Midpoint minute: 130 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 127-135
#   Midpoint minute: 131 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 128-136
#   Midpoint minute: 132 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 129-137
#   Midpoint minute: 133 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 130-138
#   Midpoint minute: 134 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 131-139
#   Midpoint minute: 135 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 132-140
#   Midpoint minute: 136 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 133-141
#   Midpoint minute: 137 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 134-142
#   Midpoint minute: 138 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 135-143
#   Midpoint minute: 139 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 136-144
#   Midpoint minute: 140 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 137-145
#   Midpoint minute: 141 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 138-146
#   Midpoint minute: 142 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 139-147
#   Midpoint minute: 143 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 140-148
#   Midpoint minute: 144 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 141-149
#   Midpoint minute: 145 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 142-150
#   Midpoint minute: 146 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 143-151
#   Midpoint minute: 147 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 144-152
#   Midpoint minute: 148 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 145-153
#   Midpoint minute: 149 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 146-154
#   Midpoint minute: 150 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 147-155
#   Midpoint minute: 151 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 148-156
#   Midpoint minute: 152 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 149-157
#   Midpoint minute: 153 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 150-158
#   Midpoint minute: 154 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 151-159
#   Midpoint minute: 155 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 152-160
#   Midpoint minute: 156 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 153-161
#   Midpoint minute: 157 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 154-162
#   Midpoint minute: 158 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 155-163
#   Midpoint minute: 159 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 156-164
#   Midpoint minute: 160 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 157-165
#   Midpoint minute: 161 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 158-166
#   Midpoint minute: 162 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 159-167
#   Midpoint minute: 163 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 160-168
#   Midpoint minute: 164 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 161-169
#   Midpoint minute: 165 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 162-170
#   Midpoint minute: 166 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 163-171
#   Midpoint minute: 167 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 164-172
#   Midpoint minute: 168 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 165-173
#   Midpoint minute: 169 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 166-174
#   Midpoint minute: 170 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 167-175
#   Midpoint minute: 171 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 168-176
#   Midpoint minute: 172 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 169-177
#   Midpoint minute: 173 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 170-178
#   Midpoint minute: 174 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 171-179
#   Midpoint minute: 175 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 172-180
#   Midpoint minute: 176 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 173-181
#   Midpoint minute: 177 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 174-182
#   Midpoint minute: 178 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 175-183
#   Midpoint minute: 179 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 176-184
#   Midpoint minute: 180 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 177-185
#   Midpoint minute: 181 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 178-186
#   Midpoint minute: 182 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 179-187
#   Midpoint minute: 183 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 180-188
#   Midpoint minute: 184 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 181-189
#   Midpoint minute: 185 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 182-190
#   Midpoint minute: 186 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 183-191
#   Midpoint minute: 187 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 184-192
#   Midpoint minute: 188 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 185-193
#   Midpoint minute: 189 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 186-194
#   Midpoint minute: 190 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 187-195
#   Midpoint minute: 191 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 188-196
#   Midpoint minute: 192 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 189-197
#   Midpoint minute: 193 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 190-198
#   Midpoint minute: 194 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 191-199
#   Midpoint minute: 195 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 192-200
#   Midpoint minute: 196 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 193-201
#   Midpoint minute: 197 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 194-202
#   Midpoint minute: 198 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 195-203
#   Midpoint minute: 199 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 196-204
#   Midpoint minute: 200 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 197-205
#   Midpoint minute: 201 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 198-206
#   Midpoint minute: 202 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 199-207
#   Midpoint minute: 203 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 200-208
#   Midpoint minute: 204 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 201-209
#   Midpoint minute: 205 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 202-210
#   Midpoint minute: 206 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 203-211
#   Midpoint minute: 207 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 204-212
#   Midpoint minute: 208 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 205-213
#   Midpoint minute: 209 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 206-214
#   Midpoint minute: 210 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 207-215
#   Midpoint minute: 211 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 208-216
#   Midpoint minute: 212 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 209-217
#   Midpoint minute: 213 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 210-218
#   Midpoint minute: 214 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 211-219
#   Midpoint minute: 215 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 212-220
#   Midpoint minute: 216 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 213-221
#   Midpoint minute: 217 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 214-222
#   Midpoint minute: 218 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 215-223
#   Midpoint minute: 219 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 216-224
#   Midpoint minute: 220 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 217-225
#   Midpoint minute: 221 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 218-226
#   Midpoint minute: 222 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 219-227
#   Midpoint minute: 223 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 220-228
#   Midpoint minute: 224 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 221-229
#   Midpoint minute: 225 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 222-230
#   Midpoint minute: 226 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 223-231
#   Midpoint minute: 227 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 224-232
#   Midpoint minute: 228 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 225-233
#   Midpoint minute: 229 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 226-234
#   Midpoint minute: 230 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 227-235
#   Midpoint minute: 231 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 228-236
#   Midpoint minute: 232 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 229-237
#   Midpoint minute: 233 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 230-238
#   Midpoint minute: 234 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 231-239
#   Midpoint minute: 235 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 232-240
#   Midpoint minute: 236 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 233-241
#   Midpoint minute: 237 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 234-242
#   Midpoint minute: 238 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 235-243
#   Midpoint minute: 239 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 236-244
#   Midpoint minute: 240 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 237-245
#   Midpoint minute: 241 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 238-246
#   Midpoint minute: 242 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 239-247
#   Midpoint minute: 243 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 240-248
#   Midpoint minute: 244 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 241-249
#   Midpoint minute: 245 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 242-250
#   Midpoint minute: 246 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 243-251
#   Midpoint minute: 247 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 244-252
#   Midpoint minute: 248 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 245-253
#   Midpoint minute: 249 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 246-254
#   Midpoint minute: 250 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 247-255
#   Midpoint minute: 251 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 248-256
#   Midpoint minute: 252 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 249-257
#   Midpoint minute: 253 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 250-258
#   Midpoint minute: 254 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 251-259
#   Midpoint minute: 255 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 252-260
#   Midpoint minute: 256 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 253-261
#   Midpoint minute: 257 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 254-262
#   Midpoint minute: 258 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 255-263
#   Midpoint minute: 259 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 256-264
#   Midpoint minute: 260 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 257-265
#   Midpoint minute: 261 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 258-266
#   Midpoint minute: 262 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 259-267
#   Midpoint minute: 263 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 260-268
#   Midpoint minute: 264 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 261-269
#   Midpoint minute: 265 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 262-270
#   Midpoint minute: 266 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 263-271
#   Midpoint minute: 267 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 264-272
#   Midpoint minute: 268 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 265-273
#   Midpoint minute: 269 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 266-274
#   Midpoint minute: 270 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 267-275
#   Midpoint minute: 271 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 268-276
#   Midpoint minute: 272 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 269-277
#   Midpoint minute: 273 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 270-278
#   Midpoint minute: 274 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 271-279
#   Midpoint minute: 275 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 272-280
#   Midpoint minute: 276 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 273-281
#   Midpoint minute: 277 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 274-282
#   Midpoint minute: 278 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 275-283
#   Midpoint minute: 279 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 276-284
#   Midpoint minute: 280 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 277-285
#   Midpoint minute: 281 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 278-286
#   Midpoint minute: 282 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 279-287
#   Midpoint minute: 283 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 280-288
#   Midpoint minute: 284 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 281-289
#   Midpoint minute: 285 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 282-290
#   Midpoint minute: 286 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 283-291
#   Midpoint minute: 287 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 284-292
#   Midpoint minute: 288 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 285-293
#   Midpoint minute: 289 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 286-294
#   Midpoint minute: 290 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 287-295
#   Midpoint minute: 291 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 288-296
#   Midpoint minute: 292 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 289-297
#   Midpoint minute: 293 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 290-298
#   Midpoint minute: 294 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 291-299
#   Midpoint minute: 295 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 292-300
#   Midpoint minute: 296 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 293-301
#   Midpoint minute: 297 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 294-302
#   Midpoint minute: 298 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 295-303
#   Midpoint minute: 299 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 296-304
#   Midpoint minute: 300 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 297-305
#   Midpoint minute: 301 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 298-306
#   Midpoint minute: 302 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 299-307
#   Midpoint minute: 303 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 300-308
#   Midpoint minute: 304 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 301-309
#   Midpoint minute: 305 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 302-310
#   Midpoint minute: 306 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 303-311
#   Midpoint minute: 307 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 304-312
#   Midpoint minute: 308 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 305-313
#   Midpoint minute: 309 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 306-314
#   Midpoint minute: 310 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 307-315
#   Midpoint minute: 311 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 308-316
#   Midpoint minute: 312 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 309-317
#   Midpoint minute: 313 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 310-318
#   Midpoint minute: 314 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 311-319
#   Midpoint minute: 315 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 312-320
#   Midpoint minute: 316 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 313-321
#   Midpoint minute: 317 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 314-322
#   Midpoint minute: 318 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 315-323
#   Midpoint minute: 319 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 316-324
#   Midpoint minute: 320 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 317-325
#   Midpoint minute: 321 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 318-326
#   Midpoint minute: 322 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 319-327
#   Midpoint minute: 323 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 320-328
#   Midpoint minute: 324 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 321-329
#   Midpoint minute: 325 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 322-330
#   Midpoint minute: 326 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 323-331
#   Midpoint minute: 327 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 324-332
#   Midpoint minute: 328 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 325-333
#   Midpoint minute: 329 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 326-334
#   Midpoint minute: 330 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 327-335
#   Midpoint minute: 331 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 328-336
#   Midpoint minute: 332 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 329-337
#   Midpoint minute: 333 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 330-338
#   Midpoint minute: 334 -> mid_label: A
#   Assigned label: 1
# ...
# Record a20 - Window minutes 415-423
#   Midpoint minute: 419 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 416-424
#   Midpoint minute: 420 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 417-425
#   Midpoint minute: 421 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 418-426
#   Midpoint minute: 422 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 419-427
#   Midpoint minute: 423 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 420-428
#   Midpoint minute: 424 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 421-429
#   Midpoint minute: 425 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 422-430
#   Midpoint minute: 426 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 423-431
#   Midpoint minute: 427 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 424-432
#   Midpoint minute: 428 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 425-433
#   Midpoint minute: 429 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 426-434
#   Midpoint minute: 430 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 427-435
#   Midpoint minute: 431 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 428-436
#   Midpoint minute: 432 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 429-437
#   Midpoint minute: 433 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 430-438
#   Midpoint minute: 434 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 431-439
#   Midpoint minute: 435 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 432-440
#   Midpoint minute: 436 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 433-441
#   Midpoint minute: 437 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 434-442
#   Midpoint minute: 438 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 435-443
#   Midpoint minute: 439 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 436-444
#   Midpoint minute: 440 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 437-445
#   Midpoint minute: 441 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 438-446
#   Midpoint minute: 442 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 439-447
#   Midpoint minute: 443 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 440-448
#   Midpoint minute: 444 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 441-449
#   Midpoint minute: 445 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 442-450
#   Midpoint minute: 446 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 443-451
#   Midpoint minute: 447 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 444-452
#   Midpoint minute: 448 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 445-453
#   Midpoint minute: 449 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 446-454
#   Midpoint minute: 450 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 447-455
#   Midpoint minute: 451 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 448-456
#   Midpoint minute: 452 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 449-457
#   Midpoint minute: 453 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 450-458
#   Midpoint minute: 454 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 451-459
#   Midpoint minute: 455 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 452-460
#   Midpoint minute: 456 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 453-461
#   Midpoint minute: 457 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 454-462
#   Midpoint minute: 458 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 455-463
#   Midpoint minute: 459 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 456-464
#   Midpoint minute: 460 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 457-465
#   Midpoint minute: 461 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 458-466
#   Midpoint minute: 462 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 459-467
#   Midpoint minute: 463 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 460-468
#   Midpoint minute: 464 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 461-469
#   Midpoint minute: 465 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 462-470
#   Midpoint minute: 466 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 463-471
#   Midpoint minute: 467 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 464-472
#   Midpoint minute: 468 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 465-473
#   Midpoint minute: 469 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 466-474
#   Midpoint minute: 470 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 467-475
#   Midpoint minute: 471 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 468-476
#   Midpoint minute: 472 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 469-477
#   Midpoint minute: 473 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 470-478
#   Midpoint minute: 474 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 471-479
#   Midpoint minute: 475 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 472-480
#   Midpoint minute: 476 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 473-481
#   Midpoint minute: 477 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 474-482
#   Midpoint minute: 478 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 475-483
#   Midpoint minute: 479 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 476-484
#   Midpoint minute: 480 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 477-485
#   Midpoint minute: 481 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 478-486
#   Midpoint minute: 482 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 479-487
#   Midpoint minute: 483 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 480-488
#   Midpoint minute: 484 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 481-489
#   Midpoint minute: 485 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 482-490
#   Midpoint minute: 486 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 483-491
#   Midpoint minute: 487 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 484-492
#   Midpoint minute: 488 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 485-493
#   Midpoint minute: 489 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 486-494
#   Midpoint minute: 490 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 487-495
#   Midpoint minute: 491 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 488-496
#   Midpoint minute: 492 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 489-497
#   Midpoint minute: 493 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 490-498
#   Midpoint minute: 494 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 491-499
#   Midpoint minute: 495 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 492-500
#   Midpoint minute: 496 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 493-501
#   Midpoint minute: 497 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 494-502
#   Midpoint minute: 498 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 495-503
#   Midpoint minute: 499 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 496-504
#   Midpoint minute: 500 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 497-505
#   Midpoint minute: 501 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 498-506
#   Midpoint minute: 502 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 499-507
#   Midpoint minute: 503 -> mid_label: A
#   Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 500-508
#   Midpoint minute: 504 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 501-509
#   Midpoint minute: 505 -> mid_label: N
#   Assigned label: 0
# --------------------------------------------------
#
# Before balancing -> Apnea: 6186, Non-Apnea: 3686
# Target samples per class (balanced): 3686
# After balancing -> Apnea: 3686, Non-Apnea: 3686
# Training: 100%|██████████| 185/185 [02:16<00:00,  1.35it/s]
# Epoch 1/25 - Train Loss: 0.6532
# Training: 100%|██████████| 185/185 [02:15<00:00,  1.37it/s]
# Epoch 2/25 - Train Loss: 0.5426
# Training: 100%|██████████| 185/185 [02:14<00:00,  1.37it/s]
# Epoch 3/25 - Train Loss: 0.4396
# Training: 100%|██████████| 185/185 [02:14<00:00,  1.37it/s]
# Epoch 4/25 - Train Loss: 0.3550
# Training: 100%|██████████| 185/185 [02:14<00:00,  1.37it/s]
# Epoch 5/25 - Train Loss: 0.3248
# Training: 100%|██████████| 185/185 [02:14<00:00,  1.37it/s]
# Epoch 6/25 - Train Loss: 0.3121
# Training: 100%|██████████| 185/185 [02:15<00:00,  1.36it/s]
# Epoch 7/25 - Train Loss: 0.2952
# Training: 100%|██████████| 185/185 [02:14<00:00,  1.38it/s]
# Epoch 8/25 - Train Loss: 0.2794
# Training: 100%|██████████| 185/185 [02:14<00:00,  1.37it/s]
# Epoch 9/25 - Train Loss: 0.2672
# Training: 100%|██████████| 185/185 [02:15<00:00,  1.37it/s]
# Epoch 10/25 - Train Loss: 0.2557
# Training: 100%|██████████| 185/185 [02:16<00:00,  1.36it/s]
# Epoch 11/25 - Train Loss: 0.2449
# Training: 100%|██████████| 185/185 [02:16<00:00,  1.36it/s]
# Epoch 12/25 - Train Loss: 0.2311
# Training: 100%|██████████| 185/185 [02:18<00:00,  1.34it/s]
# Epoch 13/25 - Train Loss: 0.2236
# Training: 100%|██████████| 185/185 [02:16<00:00,  1.35it/s]
# Epoch 14/25 - Train Loss: 0.2163
# Training: 100%|██████████| 185/185 [02:17<00:00,  1.35it/s]
# Epoch 15/25 - Train Loss: 0.2117
# Training: 100%|██████████| 185/185 [02:14<00:00,  1.37it/s]
# Epoch 16/25 - Train Loss: 0.2098
# Training: 100%|██████████| 185/185 [02:15<00:00,  1.37it/s]
# Epoch 17/25 - Train Loss: 0.1927
# Training: 100%|██████████| 185/185 [02:14<00:00,  1.38it/s]
# Epoch 18/25 - Train Loss: 0.1897
# Training: 100%|██████████| 185/185 [02:12<00:00,  1.39it/s]
# Epoch 19/25 - Train Loss: 0.1810
# Training: 100%|██████████| 185/185 [02:12<00:00,  1.39it/s]
# Epoch 20/25 - Train Loss: 0.1873
# Training: 100%|██████████| 185/185 [02:13<00:00,  1.38it/s]
# Epoch 21/25 - Train Loss: 0.1739
# Training: 100%|██████████| 185/185 [02:13<00:00,  1.38it/s]
# Epoch 22/25 - Train Loss: 0.1716
# Training: 100%|██████████| 185/185 [02:15<00:00,  1.37it/s]
# Epoch 23/25 - Train Loss: 0.1727
# Training: 100%|██████████| 185/185 [02:13<00:00,  1.38it/s]
# Epoch 24/25 - Train Loss: 0.1746
# Training: 100%|██████████| 185/185 [02:17<00:00,  1.35it/s]
# Epoch 25/25 - Train Loss: 0.1721
#
# === Overall Metrics ===
# Accuracy: 0.9119
# F1-score (binary): 0.9113
# Cohen's Kappa: 0.8237
#
# === Classification Report (per-class) ===
#               precision    recall  f1-score   support
#
#    Non-Apnea       0.91      0.92      0.91       738
#        Apnea       0.92      0.91      0.91       737
#
#     accuracy                           0.91      1475
#    macro avg       0.91      0.91      0.91      1475
# weighted avg       0.91      0.91      0.91      1475
# Sensitivity (Recall) for class 0 (Non-Apnea): 0.9173
# Sensitivity (Recall) for class 1 (Apnea): 0.9064
#
# === Averages ===
# Macro - Precision: 0.9119, Recall: 0.9119, F1: 0.9119
# Micro - Precision: 0.9119, Recall: 0.9119, F1: 0.9119
# Weighted - Precision: 0.9119, Recall: 0.9119, F1: 0.9119
#
# Confusion Matrix (raw counts):
# [[677  61]
#  [ 69 668]]
