# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install wfdb
# !pip install neurokit2
# Out:
# Collecting wfdb
#   Downloading wfdb-4.3.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.12.13)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2025.5.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.7.2)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.26.4)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.2.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.32.4)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.15.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.20.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2025.6.15)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.26.4->wfdb) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.26.4->wfdb) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.26.4->wfdb) (2024.2.0)
# Downloading wfdb-4.3.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 9.1 MB/s eta 0:00:00
# Installing collected packages: wfdb
# Successfully installed wfdb-4.3.0
# Collecting neurokit2
#   Downloading neurokit2-0.2.12-py2.py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from neurokit2) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from neurokit2) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.2.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (3.7.2)
# Requirement already satisfied: PyWavelets>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (2.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->neurokit2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->neurokit2) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (2025.6.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->neurokit2) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->neurokit2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->neurokit2) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->neurokit2) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->neurokit2) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->neurokit2) (2024.2.0)
# Downloading neurokit2-0.2.12-py2.py3-none-any.whl (708 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.4/708.4 kB 34.5 MB/s eta 0:00:00
# Installing collected packages: neurokit2
# Successfully installed neurokit2-0.2.12

# %%
# apnea_single_split_eval.py
# High-Accuracy Apnea Detection (CNN + BiLSTM + Transformer)
# Single train/test split + class-wise ROC + detailed metrics
# Modified: Using Majority Rule for apnea labeling
# Added: Sliding window label tracking print
# Added: Count of total apnea and non-apnea labels

import os, wfdb, numpy as np
from scipy.signal import butter, filtfilt, find_peaks
from scipy.interpolate import interp1d
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, f1_score, cohen_kappa_score, classification_report,
    confusion_matrix, roc_curve, auc, precision_recall_fscore_support
)
from sklearn.preprocessing import label_binarize
from torch.utils.data import Dataset, DataLoader
import torch, torch.nn as nn, torch.nn.functional as F
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import seaborn as sns

# ---------------------------
# Config
# ---------------------------
DATASET_PATH = "/kaggle/input/adult-sleep-apnea/apnea-ecg-database-1.0.0/apnea-ecg-database-1.0.0"
ORIG_FS = 100
WIN_MIN = 5  # you can change to 5 if needed
STRIDE_MIN = 1
WIN_SIZE = ORIG_FS * 60 * WIN_MIN
STEP = ORIG_FS * 60 * STRIDE_MIN
SEQ_LEN = 300
BATCH_SIZE = 32
EPOCHS = 25
LR = 1e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42

torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

TARGET_PER_CLASS = 7071
TEST_SIZE = 0.2  # 80/20 split

# ---------------------------
# Preprocessing
# ---------------------------
def bandpass(sig, fs=ORIG_FS, low=3.0, high=45.0, order=4):
    nyq = 0.5*fs
    b, a = butter(order, [low/nyq, high/nyq], btype="band")
    return filtfilt(b, a, sig)

def detect_rpeaks(sig, fs=ORIG_FS):
    sig = sig - np.median(sig)
    th = np.median(np.abs(sig)) + 0.5*np.std(sig)
    min_dist = int(0.35*fs)
    peaks, _ = find_peaks(np.abs(sig), height=th, distance=min_dist)
    return peaks

def build_rri_ra(segment, fs=ORIG_FS):
    peaks = detect_rpeaks(segment, fs)
    if len(peaks) < 2:
        return None
    rri = np.diff(peaks) * 1000 / fs
    ra = segment[peaks[:-1]]
    return rri.astype(np.float32), ra.astype(np.float32)

def resample_seq(seq, target_len=SEQ_LEN):
    if len(seq) < 2:
        return np.zeros(target_len, dtype=np.float32)
    x_old = np.linspace(0, 1, len(seq))
    x_new = np.linspace(0, 1, target_len)
    f = interp1d(x_old, seq, kind="linear", fill_value="extrapolate")
    return f(x_new).astype(np.float32)

def augment_signal(sig):
    if random.random() < 0.5:
        sig = sig + 0.01*np.random.randn(len(sig))
    if random.random() < 0.5:
        sig = sig * (0.9 + 0.2*np.random.rand())
    if random.random() < 0.3:
        shift = int(0.05*len(sig))
        sig = np.roll(sig, shift)
    return sig

# ---------------------------
# Index Builder with Majority Rule
# ---------------------------
def build_index(records, win_min=WIN_MIN, print_windows=False):
    idx = []
    for rec in records:
        try:
            ann = wfdb.rdann(os.path.join(DATASET_PATH, rec), "apn")
            labels = ann.symbol
            total_len = wfdb.rdrecord(os.path.join(DATASET_PATH, rec)).p_signal.shape[0]
        except Exception:
            continue

        starts = range(0, total_len - WIN_SIZE + 1, STEP)
        for s in starts:
            start_min = s // (ORIG_FS * 60)
            end_min = start_min + win_min
            window_labels = labels[start_min:end_min]

            if len(window_labels) < win_min:
                continue

            # ---- Majority Rule ----
            apnea_count = window_labels.count("A")
            non_apnea_count = window_labels.count("N")

            if apnea_count > non_apnea_count:
                lab = 1   # Apnea
                maj_label = "A"
            else:
                lab = 0   # Non-Apnea (default if tie)
                maj_label = "N"

            idx.append((rec, s, lab))

            # Print info if requested
            if print_windows:
                print(f"Record {rec} - Window minutes {start_min}-{end_min-1}")
                print(f"  Labels in window: {window_labels}")
                print(f"  Apnea count: {apnea_count}, Non-apnea count: {non_apnea_count}")
                print(f"  Majority label: {maj_label} -> Assigned label: {lab}")
                print("-"*50)

    return idx

# ---------------------------
# Dataset class
# ---------------------------
class ApneaDataset(Dataset):
    def __init__(self, index, seq_len=SEQ_LEN, augment=False):
        self.seq_len = seq_len
        self.augment = augment
        random.shuffle(index)
        self.index = index

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        rec, s, label = self.index[idx]
        rec_path = os.path.join(DATASET_PATH, rec)
        sig = wfdb.rdrecord(rec_path).p_signal[:, 0].astype(np.float32)

        window = sig[s:s + WIN_SIZE]
        if self.augment:
            window = augment_signal(window)

        window = bandpass(window)
        result = build_rri_ra(window)

        if result is None:
            feat_seq = np.zeros((self.seq_len, 2), dtype=np.float32)
        else:
            rri, ra = result
            rri = (rri - np.mean(rri)) / (np.std(rri) + 1e-6)
            ra = (ra - np.mean(ra)) / (np.std(ra) + 1e-6)
            feat_seq = np.stack(
                [resample_seq(rri, self.seq_len),
                 resample_seq(ra, self.seq_len)],
                axis=1
            )

        return torch.from_numpy(feat_seq), torch.tensor(label, dtype=torch.long)

# ---------------------------
# Model definitions
# ---------------------------
class BranchCNNLSTM(nn.Module):
    def __init__(self, in_ch=2, conv_ch=64, hidden=128):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(in_ch, conv_ch, 7, padding=3), nn.ReLU(), nn.BatchNorm1d(conv_ch),
            nn.Conv1d(conv_ch, conv_ch, 5, padding=2), nn.ReLU(), nn.BatchNorm1d(conv_ch),
            nn.Conv1d(conv_ch, conv_ch, 3, padding=1), nn.ReLU(), nn.BatchNorm1d(conv_ch),
        )
        self.pool = nn.AdaptiveAvgPool1d(100)
        self.lstm = nn.LSTM(conv_ch, hidden, batch_first=True, bidirectional=True)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.conv(x)
        x = self.pool(x)
        x = x.permute(0, 2, 1)
        _, (h, _) = self.lstm(x)
        return torch.cat([h[-2], h[-1]], dim=1)

class ApneaNet(nn.Module):
    def __init__(self, hidden=128, proj_dim=256):
        super().__init__()
        self.branch = BranchCNNLSTM(2, 64, hidden)
        self.proj = nn.Linear(hidden*2, proj_dim)
        encoder = nn.TransformerEncoderLayer(
            d_model=proj_dim, nhead=8, dim_feedforward=512, dropout=0.3, batch_first=True
        )
        self.trans = nn.TransformerEncoder(encoder, num_layers=3)
        self.fc = nn.Sequential(
            nn.Linear(proj_dim, 128), nn.ReLU(), nn.Dropout(0.5),
            nn.Linear(128, 2)
        )

    def forward(self, x):
        bfeat = self.branch(x)
        tokens = self.proj(bfeat).unsqueeze(1)
        out = self.trans(tokens).mean(dim=1)
        return self.fc(out)

# ---------------------------
# Training and evaluation
# ---------------------------
def train_one_epoch(model, loader, opt, crit):
    model.train()
    total_loss = 0.0
    pbar = tqdm(loader, desc="Training")
    for X, y in pbar:
        X, y = X.to(DEVICE), y.to(DEVICE)
        opt.zero_grad()
        out = model(X)
        loss = crit(out, y)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 5.0)
        opt.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader):
    model.eval()
    preds, gts, probs = [], [], []
    with torch.no_grad():
        for X, y in loader:
            X = X.to(DEVICE)
            out = model(X)
            p = F.softmax(out, dim=1).cpu().numpy()
            pred = out.argmax(1).cpu().tolist()
            preds += pred
            gts += y.tolist()
            probs += p.tolist()
    return np.array(gts), np.array(preds), np.array(probs)

def plot_confusion(cm, fold_label=""):
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=["Non-Apnea","Apnea"], yticklabels=["Non-Apnea","Apnea"])
    plt.title(f"Confusion Matrix {fold_label}")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

def plot_classwise_roc(gts, probs, class_names=["Non-Apnea","Apnea"]):
    if probs.ndim == 1 or probs.shape[1] == 1:
        probs = np.hstack([1 - probs, probs.reshape(-1, 1)])
    n_classes = probs.shape[1]
    y_bin = label_binarize(gts, classes=list(range(n_classes)))

    plt.figure()
    for c in range(n_classes):
        fpr, tpr, _ = roc_curve(y_bin[:, c], probs[:, c])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f"{class_names[c]} (AUC={roc_auc:.3f})")

    if n_classes > 2:
        fpr_micro, tpr_micro, _ = roc_curve(y_bin.ravel(), probs.ravel())
        auc_micro = auc(fpr_micro, tpr_micro)
        plt.plot(fpr_micro, tpr_micro, linestyle="--",
                 label=f"Micro-average (AUC={auc_micro:.3f})")

    plt.plot([0,1],[0,1],"--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("Class-wise ROC Curves")
    plt.legend(loc="lower right")
    plt.show()

# ---------------------------
# Main
# ---------------------------
if __name__ == "__main__":
    records = [f"a{str(i).zfill(2)}" for i in range(1, 21)]

    # ---------------------------
    # Build index and print sliding window labels
    # ---------------------------
    index = build_index(records, win_min=WIN_MIN, print_windows=True)
    if len(index) == 0:
        raise RuntimeError("No index entries found.")

    pos_list = [x for x in index if x[2] == 1]
    neg_list = [x for x in index if x[2] == 0]

    def get_fixed_samples(lst, target, rng_seed=SEED):
        random.seed(rng_seed)
        if len(lst) >= target:
            return random.sample(lst, target)
        else:
            extra = random.choices(lst, k=(target - len(lst)))
            return lst + extra

    pos_samples = get_fixed_samples(pos_list, TARGET_PER_CLASS)
    neg_samples = get_fixed_samples(neg_list, TARGET_PER_CLASS)

    balanced_index = pos_samples + neg_samples
    random.shuffle(balanced_index)

    labels = np.array([x[2] for x in balanced_index])

    train_idx, test_idx = train_test_split(
        np.arange(len(balanced_index)), test_size=TEST_SIZE,
        stratify=labels, random_state=SEED
    )
    train_index = [balanced_index[i] for i in train_idx]
    test_index = [balanced_index[i] for i in test_idx]

    train_ds = ApneaDataset(train_index, augment=True)
    test_ds = ApneaDataset(test_index, augment=False)
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE)

    model = ApneaNet().to(DEVICE)
    opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=EPOCHS)
    crit = nn.CrossEntropyLoss()

    for ep in range(EPOCHS):
        loss = train_one_epoch(model, train_loader, opt, crit)
        scheduler.step()
        print(f"Epoch {ep+1}/{EPOCHS} - Train Loss: {loss:.4f}")

    gts, preds, probs = evaluate(model, test_loader)

    if probs.ndim == 1 or probs.shape[1] == 1:
        probs = np.hstack([1 - probs, probs.reshape(-1, 1)])

    acc = accuracy_score(gts, preds)
    f1 = f1_score(gts, preds, zero_division=0)
    kappa = cohen_kappa_score(gts, preds)
    print("\n=== Overall Metrics ===")
    print(f"Accuracy: {acc:.4f}")
    print(f"F1-score (binary): {f1:.4f}")
    print(f"Cohen's Kappa: {kappa:.4f}")

    print("\n=== Classification Report (per-class) ===")
    print(classification_report(gts, preds, target_names=["Non-Apnea","Apnea"], zero_division=0))

    cm = confusion_matrix(gts, preds)
    plot_confusion(cm)

    sens = []
    for i in range(cm.shape[0]):
        tp = cm[i, i]
        fn = cm[i, :].sum() - tp
        recall_i = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        sens.append(recall_i)
        print(f"Sensitivity (Recall) for class {i} ({'Non-Apnea' if i==0 else 'Apnea'}): {recall_i:.4f}")

    p_r_f_macro = precision_recall_fscore_support(gts, preds, average="macro", zero_division=0)
    p_r_f_micro = precision_recall_fscore_support(gts, preds, average="micro", zero_division=0)
    p_r_f_weighted = precision_recall_fscore_support(gts, preds, average="weighted", zero_division=0)
    print("\n=== Averages ===")
    print(f"Macro - Precision: {p_r_f_macro[0]:.4f}, Recall: {p_r_f_macro[1]:.4f}, F1: {p_r_f_macro[2]:.4f}")
    print(f"Micro - Precision: {p_r_f_micro[0]:.4f}, Recall: {p_r_f_micro[1]:.4f}, F1: {p_r_f_micro[2]:.4f}")
    print(f"Weighted - Precision: {p_r_f_weighted[0]:.4f}, Recall: {p_r_f_weighted[1]:.4f}, F1: {p_r_f_weighted[2]:.4f}")

    class_names = ["Non-Apnea", "Apnea"]
    plot_classwise_roc(gts, probs, class_names=class_names)

    n_classes = probs.shape[1]
    y_bin = label_binarize(gts, classes=list(range(n_classes)))
    for c in range(n_classes):
        fpr, tpr, _ = roc_curve(y_bin[:, c], probs[:, c])
        roc_auc = auc(fpr, tpr)
        print(f"AUC for class {c} ({class_names[c]}): {roc_auc:.4f}")

    print("\nConfusion Matrix (raw counts):")
    print(cm)

    # ---------------------------
    # Count and print total apnea vs non-apnea labels
    # ---------------------------
    apnea_count = np.sum(labels == 1)
    non_apnea_count = np.sum(labels == 0)
    print(f"\nTotal Labels -> Apnea: {apnea_count}, Non-Apnea: {non_apnea_count}")
# Out:
# Record a01 - Window minutes 0-4
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 1-5
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 2-6
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 3-7
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 4-8
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 5-9
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 6-10
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 7-11
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 8-12
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 9-13
#   Labels in window: ['N', 'N', 'N', 'N', 'A']
#   Apnea count: 1, Non-apnea count: 4
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 10-14
#   Labels in window: ['N', 'N', 'N', 'A', 'A']
#   Apnea count: 2, Non-apnea count: 3
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 11-15
#   Labels in window: ['N', 'N', 'A', 'A', 'A']
#   Apnea count: 3, Non-apnea count: 2
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 12-16
#   Labels in window: ['N', 'A', 'A', 'A', 'A']
#   Apnea count: 4, Non-apnea count: 1
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 13-17
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 14-18
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 15-19
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 16-20
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 17-21
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 18-22
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 19-23
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 20-24
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 21-25
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 22-26
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 23-27
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 24-28
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 25-29
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 26-30
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 27-31
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 28-32
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 29-33
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 30-34
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 31-35
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 32-36
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 33-37
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 34-38
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 35-39
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 36-40
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 37-41
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 38-42
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 39-43
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 40-44
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 41-45
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 42-46
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 43-47
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 44-48
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 45-49
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 46-50
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 47-51
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 48-52
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 49-53
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 50-54
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 51-55
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 52-56
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 53-57
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 54-58
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 55-59
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 56-60
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 57-61
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 58-62
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 59-63
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 60-64
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 61-65
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 62-66
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 63-67
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 64-68
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 65-69
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 66-70
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 67-71
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 68-72
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 69-73
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 70-74
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 71-75
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 72-76
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 73-77
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 74-78
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 75-79
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 76-80
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 77-81
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 78-82
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 79-83
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 80-84
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 81-85
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 82-86
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 83-87
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 84-88
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 85-89
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 86-90
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 87-91
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 88-92
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 89-93
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 90-94
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 91-95
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 92-96
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 93-97
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 94-98
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 95-99
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 96-100
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 97-101
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 98-102
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 99-103
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 100-104
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 101-105
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 102-106
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 103-107
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 104-108
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 105-109
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 106-110
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 107-111
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 108-112
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 109-113
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 110-114
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 111-115
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 112-116
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 113-117
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 114-118
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 115-119
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 116-120
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 117-121
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 118-122
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 119-123
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 120-124
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 121-125
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 122-126
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 123-127
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 124-128
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 125-129
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 126-130
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 127-131
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 128-132
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 129-133
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 130-134
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 131-135
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 132-136
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 133-137
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 134-138
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 135-139
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 136-140
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 137-141
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 138-142
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 139-143
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 140-144
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 141-145
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 142-146
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 143-147
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 144-148
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 145-149
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 146-150
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 147-151
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 148-152
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 149-153
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 150-154
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 151-155
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 152-156
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 153-157
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 154-158
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 155-159
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 156-160
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 157-161
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 158-162
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 159-163
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 160-164
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 161-165
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 162-166
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 163-167
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 164-168
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 165-169
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 166-170
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 167-171
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 168-172
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 169-173
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 170-174
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 171-175
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 172-176
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 173-177
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 174-178
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 175-179
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 176-180
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 177-181
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 178-182
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 179-183
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 180-184
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 181-185
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 182-186
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 183-187
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 184-188
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 185-189
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 186-190
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 187-191
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 188-192
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 189-193
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 190-194
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 191-195
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 192-196
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 193-197
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 194-198
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 195-199
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 196-200
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 197-201
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 198-202
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 199-203
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 200-204
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 201-205
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 202-206
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 203-207
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 204-208
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 205-209
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 206-210
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 207-211
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 208-212
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 209-213
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 210-214
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 211-215
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 212-216
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 213-217
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 214-218
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 215-219
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 216-220
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 217-221
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 218-222
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 219-223
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 220-224
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 221-225
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 222-226
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 223-227
#   Labels in window: ['A', 'A', 'A', 'A', 'N']
#   Apnea count: 4, Non-apnea count: 1
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 224-228
#   Labels in window: ['A', 'A', 'A', 'N', 'N']
#   Apnea count: 3, Non-apnea count: 2
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a01 - Window minutes 225-229
#   Labels in window: ['A', 'A', 'N', 'N', 'N']
#   Apnea count: 2, Non-apnea count: 3
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 226-230
#   Labels in window: ['A', 'N', 'N', 'N', 'N']
#   Apnea count: 1, Non-apnea count: 4
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 227-231
#   Labels in window: ['N', 'N', 'N', 'N', 'A']
#   Apnea count: 1, Non-apnea count: 4
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a01 - Window minutes 228-232
#   Labels in window: ['N', 'N', 'N', 'A', 'A']
# ...
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 449-453
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 450-454
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 451-455
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 452-456
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 453-457
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 454-458
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 455-459
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 456-460
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 457-461
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 458-462
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 459-463
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 460-464
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 461-465
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 462-466
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 463-467
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 464-468
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 465-469
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 466-470
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 467-471
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 468-472
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 469-473
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 470-474
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 471-475
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 472-476
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 473-477
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 474-478
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 475-479
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 476-480
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 477-481
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 478-482
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 479-483
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 480-484
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 481-485
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 482-486
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 483-487
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 484-488
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 485-489
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 486-490
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 487-491
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 488-492
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 489-493
#   Labels in window: ['A', 'A', 'A', 'A', 'N']
#   Apnea count: 4, Non-apnea count: 1
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 490-494
#   Labels in window: ['A', 'A', 'A', 'N', 'N']
#   Apnea count: 3, Non-apnea count: 2
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 491-495
#   Labels in window: ['A', 'A', 'N', 'N', 'N']
#   Apnea count: 2, Non-apnea count: 3
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 492-496
#   Labels in window: ['A', 'N', 'N', 'N', 'N']
#   Apnea count: 1, Non-apnea count: 4
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 493-497
#   Labels in window: ['N', 'N', 'N', 'N', 'A']
#   Apnea count: 1, Non-apnea count: 4
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 494-498
#   Labels in window: ['N', 'N', 'N', 'A', 'A']
#   Apnea count: 2, Non-apnea count: 3
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 495-499
#   Labels in window: ['N', 'N', 'A', 'A', 'A']
#   Apnea count: 3, Non-apnea count: 2
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 496-500
#   Labels in window: ['N', 'A', 'A', 'A', 'A']
#   Apnea count: 4, Non-apnea count: 1
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 497-501
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 498-502
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 499-503
#   Labels in window: ['A', 'A', 'A', 'A', 'A']
#   Apnea count: 5, Non-apnea count: 0
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 500-504
#   Labels in window: ['A', 'A', 'A', 'A', 'N']
#   Apnea count: 4, Non-apnea count: 1
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 501-505
#   Labels in window: ['A', 'A', 'A', 'N', 'N']
#   Apnea count: 3, Non-apnea count: 2
#   Majority label: A -> Assigned label: 1
# --------------------------------------------------
# Record a20 - Window minutes 502-506
#   Labels in window: ['A', 'A', 'N', 'N', 'N']
#   Apnea count: 2, Non-apnea count: 3
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 503-507
#   Labels in window: ['A', 'N', 'N', 'N', 'N']
#   Apnea count: 1, Non-apnea count: 4
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 504-508
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Record a20 - Window minutes 505-509
#   Labels in window: ['N', 'N', 'N', 'N', 'N']
#   Apnea count: 0, Non-apnea count: 5
#   Majority label: N -> Assigned label: 0
# --------------------------------------------------
# Training: 100%|██████████| 354/354 [04:33<00:00,  1.29it/s]
# Epoch 1/25 - Train Loss: 0.6086
# Training: 100%|██████████| 354/354 [04:31<00:00,  1.30it/s]
# Epoch 2/25 - Train Loss: 0.3947
# Training: 100%|██████████| 354/354 [04:14<00:00,  1.39it/s]
# Epoch 3/25 - Train Loss: 0.3035
# Training: 100%|██████████| 354/354 [04:05<00:00,  1.44it/s]
# Epoch 4/25 - Train Loss: 0.2744
# Training: 100%|██████████| 354/354 [04:10<00:00,  1.41it/s]
# Epoch 5/25 - Train Loss: 0.2430
# Training: 100%|██████████| 354/354 [04:00<00:00,  1.47it/s]
# Epoch 6/25 - Train Loss: 0.2256
# Training: 100%|██████████| 354/354 [04:04<00:00,  1.45it/s]
# Epoch 7/25 - Train Loss: 0.2079
# Training: 100%|██████████| 354/354 [04:15<00:00,  1.38it/s]
# Epoch 8/25 - Train Loss: 0.1988
# Training: 100%|██████████| 354/354 [04:10<00:00,  1.41it/s]
# Epoch 9/25 - Train Loss: 0.1857
# Training: 100%|██████████| 354/354 [04:13<00:00,  1.40it/s]
# Epoch 10/25 - Train Loss: 0.1864
# Training: 100%|██████████| 354/354 [04:45<00:00,  1.24it/s]
# Epoch 11/25 - Train Loss: 0.1696
# Training: 100%|██████████| 354/354 [04:04<00:00,  1.45it/s]
# Epoch 12/25 - Train Loss: 0.1555
# Training: 100%|██████████| 354/354 [04:14<00:00,  1.39it/s]
# Epoch 13/25 - Train Loss: 0.1526
# Training: 100%|██████████| 354/354 [04:11<00:00,  1.41it/s]
# Epoch 14/25 - Train Loss: 0.1471
# Training: 100%|██████████| 354/354 [04:07<00:00,  1.43it/s]
# Epoch 15/25 - Train Loss: 0.1374
# Training: 100%|██████████| 354/354 [04:09<00:00,  1.42it/s]
# Epoch 16/25 - Train Loss: 0.1299
# Training: 100%|██████████| 354/354 [04:06<00:00,  1.43it/s]
# Epoch 17/25 - Train Loss: 0.1204
# Training: 100%|██████████| 354/354 [04:08<00:00,  1.42it/s]
# Epoch 18/25 - Train Loss: 0.1179
# Training: 100%|██████████| 354/354 [04:06<00:00,  1.44it/s]
# Epoch 19/25 - Train Loss: 0.1050
# Training: 100%|██████████| 354/354 [04:06<00:00,  1.44it/s]
# Epoch 20/25 - Train Loss: 0.1061
# Training: 100%|██████████| 354/354 [04:05<00:00,  1.44it/s]
# Epoch 21/25 - Train Loss: 0.0986
# Training: 100%|██████████| 354/354 [04:04<00:00,  1.45it/s]
# Epoch 22/25 - Train Loss: 0.0963
# Training: 100%|██████████| 354/354 [04:03<00:00,  1.45it/s]
# Epoch 23/25 - Train Loss: 0.0972
# Training: 100%|██████████| 354/354 [04:16<00:00,  1.38it/s]
# Epoch 24/25 - Train Loss: 0.0895
# Training: 100%|██████████| 354/354 [04:13<00:00,  1.40it/s]
# Epoch 25/25 - Train Loss: 0.0981
#
# === Overall Metrics ===
# Accuracy: 0.9579
# F1-score (binary): 0.9572
# Cohen's Kappa: 0.9159
#
# === Classification Report (per-class) ===
#               precision    recall  f1-score   support
#
#    Non-Apnea       0.94      0.97      0.96      1415
#        Apnea       0.97      0.94      0.96      1414
#
#     accuracy                           0.96      2829
#    macro avg       0.96      0.96      0.96      2829
# weighted avg       0.96      0.96      0.96      2829
# Sensitivity (Recall) for class 0 (Non-Apnea): 0.9739
# Sensitivity (Recall) for class 1 (Apnea): 0.9420
#
# === Averages ===
# Macro - Precision: 0.9584, Recall: 0.9579, F1: 0.9579
# Micro - Precision: 0.9579, Recall: 0.9579, F1: 0.9579
# Weighted - Precision: 0.9584, Recall: 0.9579, F1: 0.9579
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_36/774506811.py in <cell line: 0>()
#     368
#     369     class_names = ["Non-Apnea", "Apnea"]
# --> 370     plot_classwise_roc(gts, probs, class_names=class_names)
#     371
#     372     n_classes = probs.shape[1]
#
# /tmp/ipykernel_36/774506811.py in plot_classwise_roc(gts, probs, class_names)
#     261     plt.figure()
#     262     for c in range(n_classes):
# --> 263         fpr, tpr, _ = roc_curve(y_bin[:, c], probs[:, c])
#     264         roc_auc = auc(fpr, tpr)
#     265         plt.plot(fpr, tpr, label=f"{class_names[c]} (AUC={roc_auc:.3f})")
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
