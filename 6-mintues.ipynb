# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install wfdb
# !pip install neurokit2
# Out:
# Collecting wfdb
#   Downloading wfdb-4.3.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.13.2)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2025.10.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.7.2)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.26.4)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.2.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.32.5)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.15.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.10.11->wfdb) (1.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.26.4->wfdb) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2025.10.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.10.0->wfdb) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp>=3.10.11->wfdb) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.26.4->wfdb) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.26.4->wfdb) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.26.4->wfdb) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.26.4->wfdb) (2024.2.0)
# Downloading wfdb-4.3.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 2.4 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: wfdb
# Successfully installed wfdb-4.3.0
# Collecting neurokit2
#   Downloading neurokit2-0.2.12-py2.py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from neurokit2) (2.32.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from neurokit2) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.2.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (3.7.2)
# Requirement already satisfied: PyWavelets>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.0->neurokit2) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->neurokit2) (2.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->neurokit2) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->neurokit2) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->neurokit2) (1.17.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->neurokit2) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->neurokit2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->neurokit2) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->neurokit2) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->neurokit2) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->neurokit2) (2024.2.0)
# Downloading neurokit2-0.2.12-py2.py3-none-any.whl (708 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.4/708.4 kB 25.0 MB/s eta 0:00:00
# Installing collected packages: neurokit2
# Successfully installed neurokit2-0.2.12

# %%
# apnea_single_split_eval.py
# High-Accuracy Apnea Detection (CNN + BiLSTM + Transformer)
# Single train/test split + class-wise ROC + detailed metrics
# Modified: 6-minute window + label from ONLY the 6th minute

import os, wfdb, numpy as np
from scipy.signal import butter, filtfilt, find_peaks
from scipy.interpolate import interp1d
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, f1_score, cohen_kappa_score, classification_report,
    confusion_matrix, roc_curve, auc, precision_recall_fscore_support
)
from sklearn.preprocessing import label_binarize
from torch.utils.data import Dataset, DataLoader
import torch, torch.nn as nn, torch.nn.functional as F
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
import seaborn as sns

# ---------------------------
# Config
# ---------------------------
DATASET_PATH = "/kaggle/input/final-apnea-dataset/apnea-ecg-database-1.0.0"
ORIG_FS = 100
WIN_MIN = 6     # 6-minute window (updated)
STRIDE_MIN = 1
WIN_SIZE = ORIG_FS * 60 * WIN_MIN
STEP = ORIG_FS * 60 * STRIDE_MIN
SEQ_LEN = 300
BATCH_SIZE = 32
EPOCHS = 25
LR = 1e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42

torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

TARGET_PER_CLASS = 7071
TEST_SIZE = 0.2  # 80/20 split

# ---------------------------
# Preprocessing
# ---------------------------
def bandpass(sig, fs=ORIG_FS, low=3.0, high=45.0, order=4):
    nyq = 0.5*fs
    b, a = butter(order, [low/nyq, high/nyq], btype="band")
    return filtfilt(b, a, sig)

def detect_rpeaks(sig, fs=ORIG_FS):
    sig = sig - np.median(sig)
    th = np.median(np.abs(sig)) + 0.5*np.std(sig)
    min_dist = int(0.35*fs)
    peaks, _ = find_peaks(np.abs(sig), height=th, distance=min_dist)
    return peaks

def build_rri_ra(segment, fs=ORIG_FS):
    peaks = detect_rpeaks(segment, fs)
    if len(peaks) < 2:
        return None
    rri = np.diff(peaks) * 1000 / fs
    ra = segment[peaks[:-1]]
    return rri.astype(np.float32), ra.astype(np.float32)

def resample_seq(seq, target_len=SEQ_LEN):
    if len(seq) < 2:
        return np.zeros(target_len, dtype=np.float32)
    x_old = np.linspace(0, 1, len(seq))
    x_new = np.linspace(0, 1, target_len)
    f = interp1d(x_old, seq, kind="linear", fill_value="extrapolate")
    return f(x_new).astype(np.float32)

def augment_signal(sig):
    if random.random() < 0.5:
        sig = sig + 0.01*np.random.randn(len(sig))
    if random.random() < 0.5:
        sig = sig * (0.9 + 0.2*np.random.rand())
    if random.random() < 0.3:
        shift = int(0.05*len(sig))
        sig = np.roll(sig, shift)
    return sig

# ---------------------------
# Index Builder (UPDATED)
# ---------------------------
def build_index(records, win_min=WIN_MIN, print_windows=False):
    """
    New rule: label = label of the 6th minute only.
    If window covers minutes m ... m+5,
    label is labels[m+5].
    """
    idx = []
    for rec in records:
        try:
            ann = wfdb.rdann(os.path.join(DATASET_PATH, rec), "apn")
            labels = ann.symbol  # minute-wise labels
            total_len = wfdb.rdrecord(os.path.join(DATASET_PATH, rec)).p_signal.shape[0]
        except Exception:
            continue

        starts = range(0, total_len - WIN_SIZE + 1, STEP)

        for s in starts:
            start_min = s // (ORIG_FS * 60)
            end_min = start_min + win_min   # end_min = m + 6

            # needs 6 labels available
            if end_min - 1 >= len(labels):
                continue

            # --------- NEW LABEL RULE ----------
            label_symbol = labels[end_min - 1]   # 6th minute label
            lab = 1 if label_symbol == "A" else 0

            idx.append((rec, s, lab))

            if print_windows:
                print(f"Record {rec} - Window minutes {start_min}-{end_min-1}")
                print(f"  6th-minute label: {label_symbol} -> {lab}")
                print("-"*50)

    return idx

# ---------------------------
# Dataset class
# ---------------------------
class ApneaDataset(Dataset):
    def __init__(self, index, seq_len=SEQ_LEN, augment=False):
        self.seq_len = seq_len
        self.augment = augment
        random.shuffle(index)
        self.index = index

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        rec, s, label = self.index[idx]
        rec_path = os.path.join(DATASET_PATH, rec)
        sig = wfdb.rdrecord(rec_path).p_signal[:, 0].astype(np.float32)

        window = sig[s:s + WIN_SIZE]
        if self.augment:
            window = augment_signal(window)

        window = bandpass(window)
        result = build_rri_ra(window)

        if result is None:
            feat_seq = np.zeros((self.seq_len, 2), dtype=np.float32)
        else:
            rri, ra = result
            rri = (rri - np.mean(rri)) / (np.std(rri) + 1e-6)
            ra = (ra - np.mean(ra)) / (np.std(ra) + 1e-6)
            feat_seq = np.stack(
                [resample_seq(rri, self.seq_len),
                 resample_seq(ra, self.seq_len)],
                axis=1
            )

        return torch.from_numpy(feat_seq), torch.tensor(label, dtype=torch.long)

# ---------------------------
# Model definitions
# ---------------------------
class BranchCNNLSTM(nn.Module):
    def __init__(self, in_ch=2, conv_ch=64, hidden=128):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(in_ch, conv_ch, 7, padding=3), nn.ReLU(), nn.BatchNorm1d(conv_ch),
            nn.Conv1d(conv_ch, conv_ch, 5, padding=2), nn.ReLU(), nn.BatchNorm1d(conv_ch),
            nn.Conv1d(conv_ch, conv_ch, 3, padding=1), nn.ReLU(), nn.BatchNorm1d(conv_ch),
        )
        self.pool = nn.AdaptiveAvgPool1d(100)
        self.lstm = nn.LSTM(conv_ch, hidden, batch_first=True, bidirectional=True)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.conv(x)
        x = self.pool(x)
        x = x.permute(0, 2, 1)
        _, (h, _) = self.lstm(x)
        return torch.cat([h[-2], h[-1]], dim=1)

class ApneaNet(nn.Module):
    def __init__(self, hidden=128, proj_dim=256):
        super().__init__()
        self.branch = BranchCNNLSTM(2, 64, hidden)
        self.proj = nn.Linear(hidden*2, proj_dim)
        encoder = nn.TransformerEncoderLayer(
            d_model=proj_dim, nhead=8, dim_feedforward=512, dropout=0.3, batch_first=True
        )
        self.trans = nn.TransformerEncoder(encoder, num_layers=3)
        self.fc = nn.Sequential(
            nn.Linear(proj_dim, 128), nn.ReLU(), nn.Dropout(0.5),
            nn.Linear(128, 2)
        )

    def forward(self, x):
        bfeat = self.branch(x)
        tokens = self.proj(bfeat).unsqueeze(1)
        out = self.trans(tokens).mean(dim=1)
        return self.fc(out)

# ---------------------------
# Training and evaluation
# ---------------------------
def train_one_epoch(model, loader, opt, crit):
    model.train()
    total_loss = 0.0
    pbar = tqdm(loader, desc="Training")
    for X, y in pbar:
        X, y = X.to(DEVICE), y.to(DEVICE)
        opt.zero_grad()
        out = model(X)
        loss = crit(out, y)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 5.0)
        opt.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader):
    model.eval()
    preds, gts, probs = [], [], []
    with torch.no_grad():
        for X, y in loader:
            X = X.to(DEVICE)
            out = model(X)
            p = F.softmax(out, dim=1).cpu().numpy()
            pred = out.argmax(1).cpu().tolist()
            preds += pred
            gts += y.tolist()
            probs += p.tolist()
    return np.array(gts), np.array(preds), np.array(probs)

def plot_confusion(cm, fold_label=""):
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=["Non-Apnea","Apnea"], yticklabels=["Non-Apnea","Apnea"])
    plt.title(f"Confusion Matrix {fold_label}")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

def plot_classwise_roc(gts, probs, class_names=["Non-Apnea","Apnea"]):
    if probs.ndim == 1 or probs.shape[1] == 1:
        probs = np.hstack([1 - probs, probs.reshape(-1, 1)])
    n_classes = probs.shape[1]
    y_bin = label_binarize(gts, classes=list(range(n_classes)))

    plt.figure()
    for c in range(n_classes):
        fpr, tpr, _ = roc_curve(y_bin[:, c], probs[:, c])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f"{class_names[c]} (AUC={roc_auc:.3f})")

    plt.plot([0,1],[0,1],"--", color="gray")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("Class-wise ROC Curves")
    plt.legend(loc="lower right")
    plt.show()

# ---------------------------
# Main
# ---------------------------
if __name__ == "__main__":
    records = [f"a{str(i).zfill(2)}" for i in range(1, 20)]

    # -------- Build index --------
    index = build_index(records, win_min=WIN_MIN, print_windows=True)
    if len(index) == 0:
        raise RuntimeError("No index entries found.")

    pos_list = [x for x in index if x[2] == 1]
    neg_list = [x for x in index if x[2] == 0]

    def get_fixed_samples(lst, target, rng_seed=SEED):
        random.seed(rng_seed)
        if len(lst) >= target:
            return random.sample(lst, target)
        else:
            extra = random.choices(lst, k=(target - len(lst)))
            return lst + extra

    pos_samples = get_fixed_samples(pos_list, TARGET_PER_CLASS)
    neg_samples = get_fixed_samples(neg_list, TARGET_PER_CLASS)

    balanced_index = pos_samples + neg_samples
    random.shuffle(balanced_index)

    labels = np.array([x[2] for x in balanced_index])

    train_idx, test_idx = train_test_split(
        np.arange(len(balanced_index)), test_size=TEST_SIZE,
        stratify=labels, random_state=SEED
    )
    train_index = [balanced_index[i] for i in train_idx]
    test_index = [balanced_index[i] for i in test_idx]

    train_ds = ApneaDataset(train_index, augment=True)
    test_ds = ApneaDataset(test_index, augment=False)
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE)

    model = ApneaNet().to(DEVICE)
    opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=EPOCHS)
    crit = nn.CrossEntropyLoss()

    for ep in range(EPOCHS):
        loss = train_one_epoch(model, train_loader, opt, crit)
        scheduler.step()
        print(f"Epoch {ep+1}/{EPOCHS} - Train Loss: {loss:.4f}")

    gts, preds, probs = evaluate(model, test_loader)

    if probs.ndim == 1 or probs.shape[1] == 1:
        probs = np.hstack([1 - probs, probs.reshape(-1, 1)])

    acc = accuracy_score(gts, preds)
    f1 = f1_score(gts, preds, zero_division=0)
    kappa = cohen_kappa_score(gts, preds)
    print("\n=== Overall Metrics ===")
    print(f"Accuracy: {acc:.4f}")
    print(f"F1-score (binary): {f1:.4f}")
    print(f"Cohen's Kappa: {kappa:.4f}")

    print("\n=== Classification Report (per-class) ===")
    print(classification_report(gts, preds, target_names=["Non-Apnea","Apnea"], zero_division=0))

    cm = confusion_matrix(gts, preds)
    plot_confusion(cm)

    print("\nSensitivity Per Class:")
    for i in range(cm.shape[0]):
        tp = cm[i, i]
        fn = cm[i, :].sum() - tp
        recall_i = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        print(f"Class {i}: {recall_i:.4f}")

    p_r_f_macro = precision_recall_fscore_support(gts, preds, average="macro", zero_division=0)
    p_r_f_micro = precision_recall_fscore_support(gts, preds, average="micro", zero_division=0)
    p_r_f_weighted = precision_recall_fscore_support(gts, preds, average="weighted", zero_division=0)

    print("\n=== Averages ===")
    print(f"Macro - P: {p_r_f_macro[0]:.4f}, R: {p_r_f_macro[1]:.4f}, F1: {p_r_f_macro[2]:.4f}")
    print(f"Micro - P: {p_r_f_micro[0]:.4f}, R: {p_r_f_micro[1]:.4f}, F1: {p_r_f_micro[2]:.4f}")
    print(f"Weighted - P: {p_r_f_weighted[0]:.4f}, R: {p_r_f_weighted[1]:.4f}, F1: {p_r_f_weighted[2]:.4f}")

    class_names = ["Non-Apnea", "Apnea"]
    plot_classwise_roc(gts, probs, class_names=class_names)

    n_classes = probs.shape[1]
    y_bin = label_binarize(gts, classes=list(range(n_classes)))
    for c in range(n_classes):
        fpr, tpr, _ = roc_curve(y_bin[:, c], probs[:, c])
        roc_auc = auc(fpr, tpr)
        print(f"AUC for class {c} ({class_names[c]}): {roc_auc:.4f}")

    print("\nConfusion Matrix (raw counts):")
    print(cm)

    apnea_count = np.sum(labels == 1)
    non_apnea_count = np.sum(labels == 0)
    print(f"\nTotal Labels -> Apnea: {apnea_count}, Non-Apnea: {non_apnea_count}")
# Out:
# Record a01 - Window minutes 0-5
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 1-6
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 2-7
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 3-8
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 4-9
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 5-10
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 6-11
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 7-12
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 8-13
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 9-14
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 10-15
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 11-16
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 12-17
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 13-18
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 14-19
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 15-20
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 16-21
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 17-22
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 18-23
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 19-24
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 20-25
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 21-26
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 22-27
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 23-28
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 24-29
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 25-30
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 26-31
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 27-32
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 28-33
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 29-34
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 30-35
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 31-36
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 32-37
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 33-38
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 34-39
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 35-40
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 36-41
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 37-42
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 38-43
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 39-44
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 40-45
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 41-46
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 42-47
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 43-48
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 44-49
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 45-50
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 46-51
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 47-52
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 48-53
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 49-54
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 50-55
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 51-56
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 52-57
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 53-58
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 54-59
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 55-60
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 56-61
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 57-62
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 58-63
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 59-64
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 60-65
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 61-66
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 62-67
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 63-68
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 64-69
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 65-70
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 66-71
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 67-72
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 68-73
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 69-74
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 70-75
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 71-76
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 72-77
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 73-78
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 74-79
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 75-80
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 76-81
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 77-82
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 78-83
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 79-84
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 80-85
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 81-86
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 82-87
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 83-88
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 84-89
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 85-90
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 86-91
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 87-92
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 88-93
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 89-94
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 90-95
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 91-96
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 92-97
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 93-98
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 94-99
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 95-100
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 96-101
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 97-102
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 98-103
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 99-104
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 100-105
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 101-106
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 102-107
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 103-108
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 104-109
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 105-110
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 106-111
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 107-112
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 108-113
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 109-114
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 110-115
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 111-116
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 112-117
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 113-118
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 114-119
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 115-120
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 116-121
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 117-122
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 118-123
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 119-124
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 120-125
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 121-126
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 122-127
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 123-128
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 124-129
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 125-130
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 126-131
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 127-132
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 128-133
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 129-134
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 130-135
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 131-136
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 132-137
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 133-138
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 134-139
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 135-140
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 136-141
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 137-142
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 138-143
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 139-144
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 140-145
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 141-146
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 142-147
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 143-148
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 144-149
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 145-150
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 146-151
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 147-152
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 148-153
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 149-154
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 150-155
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 151-156
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 152-157
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 153-158
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 154-159
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 155-160
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 156-161
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 157-162
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 158-163
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 159-164
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 160-165
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 161-166
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 162-167
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 163-168
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 164-169
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 165-170
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 166-171
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 167-172
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 168-173
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 169-174
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 170-175
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 171-176
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 172-177
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 173-178
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 174-179
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 175-180
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 176-181
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 177-182
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 178-183
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 179-184
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 180-185
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 181-186
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 182-187
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 183-188
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 184-189
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 185-190
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 186-191
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 187-192
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 188-193
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 189-194
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 190-195
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 191-196
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 192-197
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 193-198
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 194-199
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 195-200
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 196-201
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 197-202
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 198-203
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 199-204
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 200-205
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 201-206
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 202-207
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 203-208
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 204-209
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 205-210
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 206-211
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 207-212
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 208-213
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 209-214
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 210-215
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 211-216
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 212-217
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 213-218
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 214-219
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 215-220
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 216-221
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 217-222
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 218-223
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 219-224
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 220-225
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 221-226
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 222-227
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 223-228
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 224-229
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 225-230
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 226-231
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 227-232
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 228-233
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 229-234
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 230-235
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 231-236
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 232-237
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 233-238
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 234-239
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 235-240
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 236-241
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 237-242
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 238-243
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 239-244
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 240-245
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 241-246
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 242-247
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 243-248
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 244-249
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 245-250
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 246-251
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 247-252
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 248-253
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 249-254
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 250-255
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 251-256
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 252-257
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 253-258
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 254-259
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 255-260
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 256-261
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 257-262
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 258-263
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 259-264
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 260-265
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 261-266
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 262-267
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 263-268
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 264-269
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 265-270
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 266-271
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 267-272
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 268-273
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 269-274
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 270-275
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 271-276
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 272-277
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 273-278
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 274-279
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 275-280
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 276-281
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 277-282
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 278-283
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 279-284
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 280-285
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 281-286
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 282-287
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 283-288
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 284-289
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 285-290
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 286-291
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 287-292
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 288-293
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 289-294
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 290-295
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 291-296
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 292-297
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 293-298
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 294-299
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 295-300
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 296-301
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 297-302
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 298-303
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 299-304
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 300-305
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 301-306
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 302-307
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 303-308
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 304-309
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 305-310
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 306-311
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 307-312
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 308-313
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 309-314
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 310-315
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 311-316
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 312-317
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 313-318
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 314-319
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 315-320
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 316-321
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 317-322
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 318-323
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 319-324
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 320-325
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 321-326
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 322-327
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 323-328
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 324-329
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 325-330
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 326-331
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 327-332
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 328-333
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 329-334
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 330-335
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 331-336
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 332-337
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 333-338
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 334-339
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 335-340
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 336-341
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 337-342
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 338-343
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 339-344
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 340-345
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 341-346
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 342-347
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 343-348
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 344-349
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 345-350
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 346-351
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 347-352
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 348-353
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a01 - Window minutes 349-354
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 350-355
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 351-356
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 352-357
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 353-358
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 354-359
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 355-360
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 356-361
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 357-362
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 358-363
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 359-364
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 360-365
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 361-366
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 362-367
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 363-368
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 364-369
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 365-370
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 366-371
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 367-372
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 368-373
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 369-374
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 370-375
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 371-376
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 372-377
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 373-378
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 374-379
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 375-380
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 376-381
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 377-382
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 378-383
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 379-384
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 380-385
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 381-386
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 382-387
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 383-388
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 384-389
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 385-390
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 386-391
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 387-392
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 388-393
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 389-394
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 390-395
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 391-396
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 392-397
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 393-398
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 394-399
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 395-400
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 396-401
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 397-402
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 398-403
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 399-404
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 400-405
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 401-406
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 402-407
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 403-408
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 404-409
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 405-410
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 406-411
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 407-412
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 408-413
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 409-414
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 410-415
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 411-416
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 412-417
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 413-418
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 414-419
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 415-420
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 416-421
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 417-422
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 418-423
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 419-424
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 420-425
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 421-426
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a01 - Window minutes 422-427
#   6th-minute label: A -> 1
# ...
# --------------------------------------------------
# Record a19 - Window minutes 390-395
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 391-396
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 392-397
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 393-398
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 394-399
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 395-400
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 396-401
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 397-402
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 398-403
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 399-404
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 400-405
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 401-406
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 402-407
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 403-408
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 404-409
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 405-410
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 406-411
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 407-412
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 408-413
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 409-414
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 410-415
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 411-416
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 412-417
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 413-418
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 414-419
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 415-420
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 416-421
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 417-422
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 418-423
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 419-424
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 420-425
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 421-426
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 422-427
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 423-428
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 424-429
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 425-430
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 426-431
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 427-432
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 428-433
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 429-434
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 430-435
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 431-436
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 432-437
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 433-438
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 434-439
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 435-440
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 436-441
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 437-442
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 438-443
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 439-444
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 440-445
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 441-446
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 442-447
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 443-448
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 444-449
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 445-450
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 446-451
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 447-452
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 448-453
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 449-454
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 450-455
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 451-456
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 452-457
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 453-458
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 454-459
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 455-460
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 456-461
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 457-462
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 458-463
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 459-464
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 460-465
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 461-466
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 462-467
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 463-468
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 464-469
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 465-470
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 466-471
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 467-472
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 468-473
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 469-474
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 470-475
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 471-476
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 472-477
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 473-478
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 474-479
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 475-480
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 476-481
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 477-482
#   6th-minute label: N -> 0
# --------------------------------------------------
# Record a19 - Window minutes 478-483
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 479-484
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 480-485
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 481-486
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 482-487
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 483-488
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 484-489
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 485-490
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 486-491
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 487-492
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 488-493
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 489-494
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 490-495
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 491-496
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 492-497
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 493-498
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 494-499
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 495-500
#   6th-minute label: A -> 1
# --------------------------------------------------
# Record a19 - Window minutes 496-501
#   6th-minute label: A -> 1
# --------------------------------------------------
# Training: 100%|██████████| 354/354 [04:06<00:00,  1.43it/s]
# Epoch 1/25 - Train Loss: 0.5940
# Training: 100%|██████████| 354/354 [04:05<00:00,  1.44it/s]
# Epoch 2/25 - Train Loss: 0.3870
# Training: 100%|██████████| 354/354 [04:03<00:00,  1.45it/s]
# Epoch 3/25 - Train Loss: 0.3148
# Training: 100%|██████████| 354/354 [04:09<00:00,  1.42it/s]
# Epoch 4/25 - Train Loss: 0.2818
# Training: 100%|██████████| 354/354 [04:08<00:00,  1.43it/s]
# Epoch 5/25 - Train Loss: 0.2532
# Training: 100%|██████████| 354/354 [04:02<00:00,  1.46it/s]
# Epoch 6/25 - Train Loss: 0.2416
# Training: 100%|██████████| 354/354 [04:03<00:00,  1.45it/s]
# Epoch 7/25 - Train Loss: 0.2215
# Training: 100%|██████████| 354/354 [04:02<00:00,  1.46it/s]
# Epoch 8/25 - Train Loss: 0.2062
# Training: 100%|██████████| 354/354 [04:02<00:00,  1.46it/s]
# Epoch 9/25 - Train Loss: 0.1948
# Training: 100%|██████████| 354/354 [04:01<00:00,  1.46it/s]
# Epoch 10/25 - Train Loss: 0.1818
# Training: 100%|██████████| 354/354 [03:59<00:00,  1.48it/s]
# Epoch 11/25 - Train Loss: 0.1723
# Training: 100%|██████████| 354/354 [04:04<00:00,  1.45it/s]
# Epoch 12/25 - Train Loss: 0.1590
# Training: 100%|██████████| 354/354 [04:06<00:00,  1.44it/s]
# Epoch 13/25 - Train Loss: 0.1509
# Training: 100%|██████████| 354/354 [04:05<00:00,  1.44it/s]
# Epoch 14/25 - Train Loss: 0.1417
# Training: 100%|██████████| 354/354 [04:03<00:00,  1.46it/s]
# Epoch 15/25 - Train Loss: 0.1400
# Training: 100%|██████████| 354/354 [04:03<00:00,  1.45it/s]
# Epoch 16/25 - Train Loss: 0.1273
# Training: 100%|██████████| 354/354 [04:03<00:00,  1.45it/s]
# Epoch 17/25 - Train Loss: 0.1202
# Training: 100%|██████████| 354/354 [04:12<00:00,  1.40it/s]
# Epoch 18/25 - Train Loss: 0.1166
# Training: 100%|██████████| 354/354 [04:10<00:00,  1.41it/s]
# Epoch 19/25 - Train Loss: 0.1090
# Training: 100%|██████████| 354/354 [04:12<00:00,  1.40it/s]
# Epoch 20/25 - Train Loss: 0.1028
# Training: 100%|██████████| 354/354 [04:09<00:00,  1.42it/s]
# Epoch 21/25 - Train Loss: 0.1037
# Training: 100%|██████████| 354/354 [04:07<00:00,  1.43it/s]
# Epoch 22/25 - Train Loss: 0.1014
# Training: 100%|██████████| 354/354 [04:10<00:00,  1.41it/s]
# Epoch 23/25 - Train Loss: 0.0988
# Training: 100%|██████████| 354/354 [04:13<00:00,  1.40it/s]
# Epoch 24/25 - Train Loss: 0.0949
# Training: 100%|██████████| 354/354 [04:09<00:00,  1.42it/s]
# Epoch 25/25 - Train Loss: 0.0930
#
# === Overall Metrics ===
# Accuracy: 0.9555
# F1-score (binary): 0.9554
# Cohen's Kappa: 0.9109
#
# === Classification Report (per-class) ===
#               precision    recall  f1-score   support
#
#    Non-Apnea       0.95      0.96      0.96      1415
#        Apnea       0.96      0.95      0.96      1414
#
#     accuracy                           0.96      2829
#    macro avg       0.96      0.96      0.96      2829
# weighted avg       0.96      0.96      0.96      2829
# Sensitivity Per Class:
# Class 0: 0.9569
# Class 1: 0.9540
#
# === Averages ===
# Macro - P: 0.9555, R: 0.9555, F1: 0.9555
# Micro - P: 0.9555, R: 0.9555, F1: 0.9555
# Weighted - P: 0.9555, R: 0.9555, F1: 0.9555
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_48/4057205442.py in <cell line: 0>()
#     354
#     355     class_names = ["Non-Apnea", "Apnea"]
# --> 356     plot_classwise_roc(gts, probs, class_names=class_names)
#     357
#     358     n_classes = probs.shape[1]
#
# /tmp/ipykernel_48/4057205442.py in plot_classwise_roc(gts, probs, class_names)
#     255     plt.figure()
#     256     for c in range(n_classes):
# --> 257         fpr, tpr, _ = roc_curve(y_bin[:, c], probs[:, c])
#     258         roc_auc = auc(fpr, tpr)
#     259         plt.plot(fpr, tpr, label=f"{class_names[c]} (AUC={roc_auc:.3f})")
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
